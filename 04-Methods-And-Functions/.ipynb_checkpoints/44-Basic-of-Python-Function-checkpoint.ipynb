# %%
def say_hello():
    print("hello")
    print("are")
    print("you")

# %%
say_hello()
# Out:
# hello
# are
# you

# %%
say_hello
# Out:
# <function __main__.say_hello()>

# %%
help(say_hello)
# Out:
# Help on function say_hello in module __main__:
#
# say_hello()

# %%
def say_hello(name):
    print(f'Hello {name}')

# %%
say_hello("Shubham")
# Out:
# Hello Shubham

# %%
# Error Case function call without argument leads to an error poping off
say_hello()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-156648eef276> in <module>
#       1 # Error Case function call without argument leads to an error poping off
# ----> 2 say_hello()
#
# TypeError: say_hello() missing 1 required positional argument: 'name'

# %%
# To Handle Adove Error proide Deafault value
def say_hello(name = "Default"):
    print(f'Hello {name}')

# %%
say_hello()
# Out:
# Hello Default

# %% [markdown]
# ## return keyword

# %%
def add_num(num1, num2):
    return num1 + num2

# %%
result = add_num(10, 20)

# %%
result
# Out:
# 30

# %%
def print_result(a, b):
    print(a + b)

# %%
def return_result(a, b):
    return a + b

# %%
print_result(10, 20)
# Out:
# 30

# %%
result = print_result(10, 20)
# Out:
# 30

# %%
type(result)
# Out:
# NoneType

# %%
result = return_result(10, 20)

# %%
result
# Out:
# 30

# %%
def sum_numbers(num1, num2):
    return num1 + num2

# %%
sum_numbers(10, 20)
# Out:
# 30

# %%
sum_numbers('10', '20')
# Out:
# '1020'

# %% [markdown]
# # Logic with Function

# %%
def is_even(number):
    return number % 2 == 0

# %%
is_even(20)
# Out:
# True

# %%
is_even(21)
# Out:
# False

# %%
# Return True if any number is even inside a list

def any_even_present(num_list):
    
    for num in num_list:
        if num % 2 == 0:
            return True
        else:
            # Do Nothing
            pass
    
    return False

# %%
mylist = [2, 1, 3, 5, 7, 9]
any_even_present(mylist)
# Out:
# True

# %%
# Return all the Even number in a list

def return_all_even(num_list):
    
    even_numbers = []
    for num in num_list:
        if num % 2 == 0:
            even_numbers.append(num)
        else:
            pass
    
    return even_numbers

# %%
mylist = [2, 1, 3, 5, 7, 9]
return_all_even(mylist)
# Out:
# [2]

# %% [markdown]
# # Tuple Unpacking with Python Function

# %%
stock_prices = [('APPL', 200), ('GGOG', 400), ('MSFT', 100)]

# %%
for item in stock_prices:
    print(item)
# Out:
# ('APPL', 200)
# ('GGOG', 400)
# ('MSFT', 100)

# %%
for ticker, price in stock_prices:
    print(ticker)
# Out:
# APPL
# GGOG
# MSFT

# %%
work_hours = [('Abby', 100), ('Billy', 400), ('Cassie', 800)]

# %%
def employee_check(emp_data):
    
    current_max = 0
    employee_of_month = ''
    
    for emp_name, work_hr in emp_data:
        if work_hr > current_max:
            current_max = work_hr
            employee_of_month = emp_name
        else:
            pass
        
    # Return
    return employee_of_month, current_max

# %%
name, hours = employee_check(work_hours)

# %%
name
# Out:
# 'Cassie'

# %%
hours
# Out:
# 800

# %%
name, hours, loc = employee_check(work_hours)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-76-288ca4508287> in <module>
# ----> 1 name, hours, loc = employee_check(work_hours)
#
# ValueError: not enough values to unpack (expected 3, got 2)

# %%
# To handle above type of error just assign returned val to one variable and explore it
res = employee_check(work_hours)

# %%
res
# Out:
# ('Cassie', 800)

# %% [markdown]
# # Intercation between Python Functions

# %%
from random import shuffle

# %%
example = [1, 2, 3, 4, 5, 6, 7]

# %%
# Inplace shuffling
shuffle(example)

# %%
example
# Out:
# [6, 5, 2, 1, 3, 7, 4]

# %%
def shuffle_list(mylist):
    shuffle(mylist)
    return mylist

# %%
result = shuffle_list(example)

# %%
result
# Out:
# [3, 6, 4, 7, 1, 5, 2]

# %%
mylist = [' ', 'O', ' ']

# %%
shuffle_list(mylist)
# Out:
# ['O', ' ', ' ']

# %%
def player_guess():
    
    guess = ''
    
    while guess not in ['0', '1', '2']:
        guess = input('Pick a Number: 0, 1, or 2')
        
    return int(guess)

# %%
myguess = player_guess()
# Out:
# Pick a Number: 0, 1, or 28
# Pick a Number: 0, 1, or 21

# %%
def check_guess(mylist, guess):
    if mylist[guess] == 'O':
        print('Correct!')
    else:
        print('Wrong Guess!')
        print(mylist)

# %%
# Initial List
mylist = [' ', ' ', 'O']

# Shuffle List
mixedup_list = shuffle_list(mylist)

# User Guess
user_guess = player_guess()

# Check Guess - (Here's where function start interacting with each other)
check_guess(mixedup_list, user_guess)
# Out:
# Pick a Number: 0, 1, or 22
# Wrong Guess!
# [' ', 'O', ' ']
